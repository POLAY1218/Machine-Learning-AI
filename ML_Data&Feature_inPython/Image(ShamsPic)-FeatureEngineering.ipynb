# %% [markdown]
# # Image feature Engineering
# #### 1.converting my picture(.jpg) into array format
# #### 2.and then turning that array back into my picture format(.jpg) using pil librabry

# %%
import matplotlib.pyplot as plt

# %%
#im = plt.imread(r'leo_a.JPG')
im = plt.imread(r'ShamsPic.JPG')

# %%
plt.imshow(im)

# %%
type(im)
# Out:
# numpy.ndarray

# %%
print(im)
# Out:
# [[[144 170 247]
#   [142 167 247]
#   [141 163 246]
#   ...
#   [ 95  99  76]
#   [ 96  98  76]
#   [ 98  97  76]]
#
#  [[143 170 247]
#   [142 167 247]
#   [141 163 246]
#   ...
#   [ 95  99  76]
#   [ 96  98  76]
#   [ 98  97  76]]
#
#  [[143 170 247]
#   [142 167 247]
#   [139 164 246]
#   ...
#   [ 95  99  76]
#   [ 96  98  76]
#   [ 97  99  77]]
#
#  ...
#
#  [[ 83  88 144]
#   [ 72  79 121]
#   [ 72  82 107]
#   ...
#   [ 87  69  55]
#   [ 83  81  66]
#   [ 72  75  58]]
#
#  [[ 81  85 120]
#   [ 79  85 109]
#   [ 73  81  94]
#   ...
#   [ 83  63  52]
#   [ 76  68  55]
#   [ 77  70  54]]
#
#  [[ 45  48  63]
#   [ 48  52  63]
#   [ 44  47  54]
#   ...
#   [ 40  34  22]
#   [ 36  36  24]
#   [ 45  46  32]]]

# %%
im.shape
# Out:
# (351, 512, 3)

# %%
xF = im.flatten() #flatterned data matrix

# %%
len(xF)
# Out:
# 539136

# %%
3*349*466
# Out:
# 487902

# %%
import matplotlib.pyplot as plt
ar = plt.imread(r'ShamsPic.jpg')
x = np.array(ar)

from PIL import Image
pic= Image.fromarray(x)
plt.imshow(pic)
# Save the image as a GIF
pic.save('ShamsPic_Copy.gif')
